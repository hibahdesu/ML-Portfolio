# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using Clustering algorithms. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions.
#
# After the above operations, you will have made cluster estimation with clustering algorithms. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - Clustering Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams["figure.figsize"] = (7,4)
import warnings

# ignore warning
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
#pip install openpyxl

# %%
df = pd.DataFrame(pd.read_excel("Online Retail.xlsx"))
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].describe(include=object).T
# Out:
#             count  unique     top  freq
# InvoiceNo  541909   25900  573585  1114

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].describe().T
# Out:
#               count      mean         std       min   25%   50%    75%  \
# Quantity   541909.0  9.552250  218.081158 -80995.00  1.00  3.00  10.00
# UnitPrice  541909.0  4.611114   96.759853 -11062.06  1.25  2.08   4.13
#
#                max
# Quantity   80995.0
# UnitPrice  38970.0

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].query("Quantity < 0 or UnitPrice < 0 ")
# Out:
#        InvoiceNo  Quantity  UnitPrice
# 141      C536379        -1      27.50
# 154      C536383        -1       4.65
# 235      C536391       -12       1.65
# 236      C536391       -24       0.29
# 237      C536391       -24       0.29
# ...          ...       ...        ...
# 540449   C581490       -11       0.83
# 541541   C581499        -1     224.69
# 541715   C581568        -5      10.95
# 541716   C581569        -1       1.25
# 541717   C581569        -5       1.25
#
# [10626 rows x 3 columns]

# %%
# Add totalPrice column
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

canceled_orders = df[df['TotalPrice'] < 0]

canceled_orders
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
canceled_orders[canceled_orders['Quantity']>0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  TotalPrice
# 299983  -11062.06         NaN  United Kingdom   -11062.06
# 299984  -11062.06         NaN  United Kingdom   -11062.06

# %% [markdown]
# Check if quantity or price = 0

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].query("UnitPrice == 0")
# Out:
#        InvoiceNo  Quantity  UnitPrice
# 622       536414        56        0.0
# 1970      536545         1        0.0
# 1971      536546         1        0.0
# 1972      536547         1        0.0
# 1987      536549         1        0.0
# ...          ...       ...        ...
# 536981    581234        27        0.0
# 538504    581406       240        0.0
# 538505    581406       300        0.0
# 538554    581408        20        0.0
# 538919    581422      -235        0.0
#
# [2515 rows x 3 columns]

# %%
df.iloc[538919,:]
# Out:
# InvoiceNo                   581422
# StockCode                    23169
# Description                smashed
# Quantity                      -235
# InvoiceDate    2011-12-08 15:24:00
# UnitPrice                      0.0
# CustomerID                     NaN
# Country             United Kingdom
# TotalPrice                    -0.0
# Name: 538919, dtype: object

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].query("Quantity == 0")
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, Quantity, UnitPrice]
# Index: []

# %%
negative_entries = df[(df['Quantity'] < 0) | (df['UnitPrice'] < 0)]

print(negative_entries[['InvoiceNo', 'Description', 'Quantity', 'UnitPrice']])
# Out:
#        InvoiceNo                       Description  Quantity  UnitPrice
# 141      C536379                          Discount        -1      27.50
# 154      C536383   SET OF 3 COLOURED  FLYING DUCKS        -1       4.65
# 235      C536391    PLASTERS IN TIN CIRCUS PARADE        -12       1.65
# 236      C536391  PACK OF 12 PINK PAISLEY TISSUES        -24       0.29
# 237      C536391  PACK OF 12 BLUE PAISLEY TISSUES        -24       0.29
# ...          ...                               ...       ...        ...
# 540449   C581490   ZINC T-LIGHT HOLDER STARS SMALL       -11       0.83
# 541541   C581499                            Manual        -1     224.69
# 541715   C581568        VICTORIAN SEWING BOX LARGE        -5      10.95
# 541716   C581569  HANGING HEART JAR T-LIGHT HOLDER        -1       1.25
# 541717   C581569     36 PENCILS TUBE RED RETROSPOT        -5       1.25
#
# [10626 rows x 4 columns]

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# hint: If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %%
df[df['InvoiceNo'].astype(str).str.contains('C')]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %% [markdown]
# Check the 2 statments:

# %%
# canceled orders by Quantity> 0 
canceled_orders = df[df['InvoiceNo'].astype(str).str.contains('C')]
canceled_orders = canceled_orders.query("Quantity > 0")
num_canceled_orders = canceled_orders['InvoiceNo'].nunique()
print("Number of canceled orders:", num_canceled_orders)
# Out:
# Number of canceled orders: 0

# %%
#  non-canceled orders by Quantity <0
canceled_orders = df[df['InvoiceNo'].astype(str).str.contains('C') == False]
canceled_orders = canceled_orders.query("Quantity < 0")

# Count the number of canceled and non-canceled orders
num_canceled_orders = canceled_orders['InvoiceNo'].nunique()

# Print the results
print("Number of canceled orders:", num_canceled_orders)
# Out:
# Number of canceled orders: 1336

# %%
canceled_orders
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2406      536589     21777         NaN       -10 2010-12-01 16:50:00
# 4347      536764    84952C         NaN       -38 2010-12-02 14:42:00
# 7188      536996     22712         NaN       -20 2010-12-03 15:30:00
# 7189      536997     22028         NaN       -20 2010-12-03 15:30:00
# 7190      536998     85067         NaN        -6 2010-12-03 15:30:00
# ...          ...       ...         ...       ...                 ...
# 535333    581210     23395       check       -26 2011-12-07 18:36:00
# 535335    581212     22578        lost     -1050 2011-12-07 18:38:00
# 535336    581213     22576       check       -30 2011-12-07 18:38:00
# 536908    581226     23090     missing      -338 2011-12-08 09:56:00
# 538919    581422     23169     smashed      -235 2011-12-08 15:24:00
#
#         UnitPrice  CustomerID         Country  TotalPrice
# 2406          0.0         NaN  United Kingdom        -0.0
# ...

# %%
canceled_orders
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2406      536589     21777         NaN       -10 2010-12-01 16:50:00
# 4347      536764    84952C         NaN       -38 2010-12-02 14:42:00
# 7188      536996     22712         NaN       -20 2010-12-03 15:30:00
# 7189      536997     22028         NaN       -20 2010-12-03 15:30:00
# 7190      536998     85067         NaN        -6 2010-12-03 15:30:00
# ...          ...       ...         ...       ...                 ...
# 535333    581210     23395       check       -26 2011-12-07 18:36:00
# 535335    581212     22578        lost     -1050 2011-12-07 18:38:00
# 535336    581213     22576       check       -30 2011-12-07 18:38:00
# 536908    581226     23090     missing      -338 2011-12-08 09:56:00
# 538919    581422     23169     smashed      -235 2011-12-08 15:24:00
#
#         UnitPrice  CustomerID         Country  TotalPrice
# 2406          0.0         NaN  United Kingdom        -0.0
# ...

# %% [markdown]
# WE will delete them

# %%
df_adj = df[df['InvoiceNo'].astype(str).str.contains('C') == False]
df_adj = df_adj.query("Quantity > 0")
df_adj
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# so now the dataframe does not include:
# - Cancelled InvoiceNO (contains C)
# - Quantity less than 0

# %% [markdown]
# #### Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df[df['UnitPrice'] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  TotalPrice
# 299983  -11062.06         NaN  United Kingdom   -11062.06
# 299984  -11062.06         NaN  United Kingdom   -11062.06

# %%
df_adj.query("Description == 'Adjust bad debt' ")
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  TotalPrice
# 299982   11062.06         NaN  United Kingdom    11062.06
# 299983  -11062.06         NaN  United Kingdom   -11062.06
# 299984  -11062.06         NaN  United Kingdom   -11062.06

# %%
df.shape
# Out:
# (541909, 9)

# %% [markdown]
# It seems it was a technical issue since it was canceled after just 1 minute.
# <br>
# If there is a CustomerID, we can make sure 100% of this conclusion

# %% [markdown]
# ### iii. Handling Missing Values

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
df_adj.CustomerID.isnull().sum()
# Out:
# 133361

# %% [markdown]
# - Maybe 1st order
# - Maybe the order without an account

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
# Delete them
df_adj = df_adj.dropna(subset=['CustomerID'])

# Check
df_adj.CustomerID.isnull().sum()
# Out:
# 0

# %% [markdown]
# **Check UnitPrice=0**

# %%
df_adj.query("UnitPrice == 0")
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 9302      537197     22841         ROUND CAKE TIN VINTAGE GREEN         1
# 33576     539263     22580         ADVENT CALENDAR GINGHAM SACK         4
# 40089     539722     22423             REGENCY CAKESTAND 3 TIER        10
# 47068     540372     22090              PAPER BUNTING RETROSPOT        24
# 47070     540372     22553               PLASTERS IN TIN SKULLS        24
# 56674     541109     22168        ORGANISER WOOD ANTIQUE WHITE          1
# 86789     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16
# 130188    547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36
# 139453    548318     22055   MINI CAKE STAND  HANGING STRAWBERY         5
# 145208    548871     22162          HEART GARLAND RUSTIC PADDED         2
# 157042    550188     22636   CHILDS BREAKFAST SET CIRCUS PARADE         1
# 187613    553000     47566                        PARTY BUNTING         4
# ...

# %%
df_adj.query("UnitPrice == 0").shape
# Out:
# (40, 9)

# %% [markdown]
# Since it does not make since that large quantities with 0 price & it is just 40 observations
# <br>
# We decide to remove them

# %%
# Remove them
df_adj = df_adj.query("UnitPrice > 0")

# Check
df_adj.query("UnitPrice == 0").shape
# Out:
# (0, 9)

# %% [markdown]
# **Check Duplicates**

# %%
# count them
df_adj.duplicated().sum()
# Out:
# 5192

# %%
# delete them
df_adj.drop_duplicates(inplace = True)

# %%
# Check
df_adj.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Lets check if each Stockcode has one corresponding Description**

# %%
df_stock = df_adj.groupby("StockCode", as_index=False)[["Description"]].nunique()
df_stock
# Out:
#      StockCode  Description
# 0        10002            1
# 1        10080            1
# 2        10120            1
# 3        10125            1
# 4        10133            1
# ...        ...          ...
# 3660        C2            1
# 3661       DOT            1
# 3662         M            1
# 3663      PADS            1
# 3664      POST            1
#
# [3665 rows x 2 columns]

# %%
df_adj.groupby("StockCode", as_index=False)[["Description"]].nunique().Description.value_counts()
# Out:
# Description
# 1    3452
# 2     196
# 3      15
# 4       2
# Name: count, dtype: int64

# %% [markdown]
# So there are stockcodes have different descriptions

# %%
df_stock.query("Description != 1")
# Out:
#      StockCode  Description
# 48       20622            2
# 100      20725            2
# 192      20914            2
# 286      21109            2
# 289      21112            2
# ...        ...          ...
# 3393    85184C            2
# 3394    85185B            2
# 3438    90014A            2
# 3439    90014B            2
# 3440    90014C            2
#
# [213 rows x 2 columns]

# %%
df_adj.query('StockCode == 20622')["Description"].value_counts()
# Out:
# Description
# VIPPASSPORT COVER      21
# VIP PASSPORT COVER     11
# Name: count, dtype: int64

# %%
df_adj.query('StockCode == 20725')["Description"].value_counts()
# Out:
# Description
# LUNCH BAG RED RETROSPOT    1303
# LUNCH BAG RED SPOTTY          1
# Name: count, dtype: int64

# %%
df_adj.query('Description == "LUNCH BAG RED SPOTTY" ')["StockCode"].value_counts()
# Out:
# StockCode
# 20725    1
# Name: count, dtype: int64

# %%
df_adj.query('StockCode == "90014A" ')["Description"].value_counts()
# Out:
# Description
# SILVER/MOP ORBIT NECKLACE       7
# SILVER M.O.P. ORBIT NECKLACE    3
# Name: count, dtype: int64

# %%
df_adj.query('StockCode == "90014B" ')["Description"].value_counts()
# Out:
# Description
# GOLD M PEARL  ORBIT NECKLACE    6
# GOLD M.O.P. ORBIT NECKLACE      2
# Name: count, dtype: int64

# %%
df_adj.query('StockCode == "90014C" ')["Description"].value_counts()
# Out:
# Description
# SILVER/BLACK ORBIT NECKLACE        2
# SILVER AND BLACK ORBIT NECKLACE    1
# Name: count, dtype: int64

# %% [markdown]
# We can see:
# - they are just typo or difference in description but they seem to be the same product (Good)
# - Even A, B, C corresponding to different properties                                   (Good)
# - So we should use StockCode instead of Description

# %% [markdown]
# **Let's check if every canceled order has a corresponding normal order**

# %%
# canceled orders by Quantity> 0 
canceled_orders_ = df[df['InvoiceNo'].astype(str).str.contains('C')]
canceled_orders_ = canceled_orders_.query("Quantity < 0")
canceled_orders_
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# We will use the original dataframe that has the canceles invoices

# %%
df.groupby(["CustomerID", "StockCode"])[["InvoiceNo"]].count().query('InvoiceNo > 1')
# Out:
#                       InvoiceNo
# CustomerID StockCode
# 12346.0    23166              2
# 12347.0    20719              4
#            21041              2
#            21064              2
#            21265              2
# ...                         ...
# 18287.0    47421              2
#            72349B             2
#            85039A             2
#            85039B             3
#            85040A             2
#
# [68726 rows x 1 columns]

# %%
df.query('CustomerID == 18287.0 & StockCode == "85039B" ')
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 198741    554065    85039B  S/4 IVORY MINI ROSE CANDLE IN BOWL        60
# 198742    554065    85039B  S/4 IVORY MINI ROSE CANDLE IN BOWL        12
# 392744    570715    85039B  S/4 IVORY MINI ROSE CANDLE IN BOWL        48
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 198741 2011-05-22 10:39:00       1.45     18287.0  United Kingdom        87.0
# 198742 2011-05-22 10:39:00       1.65     18287.0  United Kingdom        19.8
# 392744 2011-10-12 10:23:00       1.45     18287.0  United Kingdom        69.6

# %%
df.query('Quantity< 0')
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
import pandas as pd

# Check for the specified conditions
result = canceled_orders_.apply(lambda row: any((df['StockCode'] == row['StockCode']) &
                                   (df['CustomerID'] == row['CustomerID']) &
                                   (df['Quantity'] == -row['Quantity'])), axis=1)

# Display the result
print(result)
# Out:
# 141       False
# 154       False
# 235       False
# 236       False
# 237       False
#           ...
# 540449    False
# 541541    False
# 541715    False
# 541716    False
# 541717    False
# Length: 9288, dtype: bool

# %%
result.to_frame().value_counts()
# Out:
# False    6022
# True     3266
# Name: count, dtype: int64

# %% [markdown]
# which means that MAYBE there are 3266 of the canceled ordered that have been already recorded as a purchase

# %%
result = result.to_frame().rename({0: "condition"}, axis=1)
result
# Out:
#         condition
# 141         False
# 154         False
# 235         False
# 236         False
# 237         False
# ...           ...
# 540449      False
# 541541      False
# 541715      False
# 541716      False
# 541717      False
#
# [9288 rows x 1 columns]

# %%
result
# Out:
#         condition
# 141         False
# 154         False
# 235         False
# 236         False
# 237         False
# ...           ...
# 540449      False
# 541541      False
# 541715      False
# 541716      False
# 541717      False
#
# [9288 rows x 1 columns]

# %%
result.query('condition == True')
# Out:
#         condition
# 1442         True
# 1983         True
# 3338         True
# 3911         True
# 3912         True
# ...           ...
# 538561       True
# 538567       True
# 540078       True
# 540079       True
# 540422       True
#
# [3266 rows x 1 columns]

# %%
df_adj.iloc[1983,:]
# Out:
# InvoiceNo                              536609
# StockCode                              84406B
# Description    CREAM CUPID HEARTS COAT HANGER
# Quantity                                    6
# InvoiceDate               2010-12-02 09:41:00
# UnitPrice                                2.75
# CustomerID                            17850.0
# Country                        United Kingdom
# TotalPrice                               16.5
# Name: 3194, dtype: object

# %%
canceled_orders_.query('  CustomerID == 17850.0')
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 86888   C543611     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -1
# 86889   C543611     22632           HAND WARMER RED RETROSPOT        -6
# 86890   C543611     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -1
# 86891   C543611     21871                 SAVE THE PLANET MUG        -1
# 86892   C543611    82494L         WOODEN FRAME ANTIQUE WHITE         -2
# 86893   C543611     21730   GLASS STAR FROSTED T-LIGHT HOLDER        -1
# 86894   C543611     21730   GLASS STAR FROSTED T-LIGHT HOLDER        -1
# 86895   C543611    82494L         WOODEN FRAME ANTIQUE WHITE        -12
# 86896   C543611     21071      VINTAGE BILLBOARD DRINK ME MUG        -6
# 86897   C543611     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -2
# 86898   C543611     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -1
# 86899   C543611     21874                   GIN AND TONIC MUG        -1
# ...

# %%
######################## try

# %%
df_temp = df.loc[:1000,:]
df_temp
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 996     536520     22100             SKULLS SQUARE TISSUE BOX         1
# 997     536520     22096      PINK PAISLEY SQUARE TISSUE BOX          1
# 998     536520     22583         PACK OF 6 HANDBAG GIFT BOXES         1
# 999     536520     21358           TOAST ITS - HAPPY BIRTHDAY         2
# 1000    536520     21123  SET/10 IVORY POLKADOT PARTY CANDLES         1
#
#              InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
# # Check for the specified conditions
# mask = canceled_orders.apply(lambda row: any((df_temp['StockCode'] == row['StockCode']) &
#                                 (df_temp['CustomerID'] == row['CustomerID']) &
#                                 (df_temp['Quantity'] == -row['Quantity'])), axis=1)

# # # Reset the index of the boolean series
# # mask = mask.reset_index(drop=True)

# # # Collect the True rows from df2 into a new dataframe
# # result_df2 = df_temp[mask.reset_index(drop=True)]

# # # Display the result
# # print(result_df2)

# %%
# mask.value_counts()

# %%
# df_temp[mask]

# %%
# Try 2 ###############################

# %%
# Merge dataframes based on specified conditions
result_df = pd.merge(canceled_orders_, df, 
                     on=['StockCode', 'CustomerID'], 
                     how='inner', 
                     suffixes=('_canceled', '_original'))

# Filter rows where Quantity_df2 is the negative of Quantity_df1
result_df = result_df[result_df['Quantity_canceled'] == -result_df['Quantity_original']]

# %%
result_df
# Out:
#       InvoiceNo_canceled StockCode                Description_canceled  \
# 1277             C536543     22355           CHARLOTTE BAG SUKI DESIGN
# 1279             C536543     22355           CHARLOTTE BAG SUKI DESIGN
# 1280             C536543     22355           CHARLOTTE BAG SUKI DESIGN
# 1283             C536543     22355           CHARLOTTE BAG SUKI DESIGN
# 1289             C536543     22355           CHARLOTTE BAG SUKI DESIGN
# ...                  ...       ...                                 ...
# 66572            C581409     23462            ROCOCO WALL MIRROR WHITE
# 66586            C581409     85127  SMALL SQUARE CUT GLASS CANDLESTICK
# 66597            C581462     16219        HOUSE SHAPE PENCIL SHARPENER
# 66599            C581462     21642           ASSORTED TUTTI FRUTTI PEN
# 66631            C581484     23843         PAPER CRAFT , LITTLE BIRDIE
#
#        Quantity_canceled InvoiceDate_canceled  UnitPrice_canceled  CustomerID  \
# ...

# %%
df_result_final = result_df[["InvoiceNo_canceled", "InvoiceNo_original",	"InvoiceDate_original","InvoiceDate_canceled" ,'StockCode', 'CustomerID', "Quantity_canceled",  "Quantity_original", "TotalPrice_canceled", "TotalPrice_original"]]
df_result_final.head(15)
# Out:
#      InvoiceNo_canceled InvoiceNo_original InvoiceDate_original  \
# 1277            C536543             546543  2011-03-14 15:40:00
# 1279            C536543             548492  2011-03-31 13:14:00
# 1280            C536543             549014  2011-04-05 15:00:00
# 1283            C536543             550359  2011-04-18 10:41:00
# 1289            C536543             554942  2011-05-27 14:01:00
# 1290            C536543             555562  2011-06-05 14:45:00
# 1304            C536543             563538  2011-08-17 11:48:00
# 1305            C536543             563771  2011-08-19 11:17:00
# 1306            C536543             564141  2011-08-23 11:47:00
# 1310            C536543             570818  2011-10-12 12:47:00
# 1365            C536548             542215  2011-01-26 12:27:00
# 1375            C536622             538174  2010-12-10 09:35:00
# 1390            C536734             540822  2011-01-11 13:25:00
# 1393            C538109             540822  2011-01-11 13:25:00
# ...

# %% [markdown]
# **It seems the canceled invoices has no corresponding purchase invoice, because we noticed that the original date is after the canceled date**

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
#df_adj.groupby("CustomerID")["InvoiceNo"].nunique()
df_d =  df_adj.groupby("InvoiceNo")[["CustomerID"]].nunique()
df_d
# Out:
#            CustomerID
# InvoiceNo
# 536365              1
# 536366              1
# 536367              1
# 536368              1
# 536369              1
# ...               ...
# 581583              1
# 581584              1
# 581585              1
# 581586              1
# 581587              1
#
# [18532 rows x 1 columns]

# %%
df_d.describe()
# Out:
#        CustomerID
# count     18532.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0

# %% [markdown]
# so there is no invoice with different Customer ID's which means there is no noisy data

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
# Calculate the average number of unique items per order
average_unique_items_per_order = df_adj.groupby('InvoiceNo')['StockCode'].nunique().mean()

# Calculate the average number of unique items per customer
average_unique_items_per_customer = df_adj.groupby('CustomerID')['StockCode'].nunique().mean()

# Print the average unique items per order
print("Average unique items per order:", round(average_unique_items_per_order,2))
# Print the average unique items per customer
print("Average unique items per customer:", round(average_unique_items_per_customer,2))
# Out:
# Average unique items per order: 20.93
# Average unique items per customer: 61.5

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
#########################################################
#COME BAAAACK
#########################################################

# %%
# groupby_invoice = pd.DataFrame(retail_df.groupby('InvoiceNo')['StockCode'].nunique())
# groupby_invoice.columns=['productsNumber']
# groupby_invoice.head()

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df_adj
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
df_adj.groupby("Country")[['TotalPrice']].sum().sort_values(by='TotalPrice', ascending=False)
# Out:
#                        TotalPrice
# Country
# United Kingdom        7285024.644
# Netherlands            285446.340
# EIRE                   265262.460
# Germany                228678.400
# France                 208934.310
# Australia              138453.810
# Spain                   61558.560
# Switzerland             56443.950
# Belgium                 41196.340
# Sweden                  38367.830
# Japan                   37416.370
# Norway                  36165.440
# Portugal                33375.840
# Finland                 22546.080
# Singapore               21279.290
# Channel Islands         20440.540
# Denmark                 18955.340
# Italy                   17483.240
# Cyprus                  13502.850
# Austria                 10198.680
# Poland                   7334.650
# Israel                   7215.840
# Greece                   4760.520
# Iceland                  4310.000
# Canada                   3666.380
# USA                      3580.390
# ...

# %% [markdown]
# 2. Visualize number of customer per country

# %%
df_vis = df_adj.groupby("Country", as_index = False)[['CustomerID']].count()
df_vis
# Out:
#                  Country  CustomerID
# 0              Australia        1181
# 1                Austria         398
# 2                Bahrain          17
# 3                Belgium        2031
# 4                 Brazil          32
# 5                 Canada         151
# 6        Channel Islands         747
# 7                 Cyprus         603
# 8         Czech Republic          25
# 9                Denmark         380
# 10                  EIRE        7226
# 11    European Community          60
# 12               Finland         685
# 13                France        8326
# 14               Germany        9025
# 15                Greece         145
# 16               Iceland         182
# 17                Israel         245
# 18                 Italy         758
# 19                 Japan         321
# 20               Lebanon          45
# 21             Lithuania          35
# 22                 Malta         112
# 23           Netherlands        2359
# ...

# %%
plt.figure(figsize=(10, 10))
sns.barplot(data=df_vis,
    x="CustomerID",
    y="Country")
# Out:
# <Axes: xlabel='CustomerID', ylabel='Country'>

# %% [markdown]
# 3. Visualize total cost per country

# %%
df_vis = df_adj.groupby("Country", as_index = False)[['TotalPrice']].sum()
df_vis
# Out:
#                  Country   TotalPrice
# 0              Australia   138453.810
# 1                Austria    10198.680
# 2                Bahrain      548.400
# 3                Belgium    41196.340
# 4                 Brazil     1143.600
# 5                 Canada     3666.380
# 6        Channel Islands    20440.540
# 7                 Cyprus    13502.850
# 8         Czech Republic      826.740
# 9                Denmark    18955.340
# 10                  EIRE   265262.460
# 11    European Community     1300.250
# 12               Finland    22546.080
# 13                France   208934.310
# 14               Germany   228678.400
# 15                Greece     4760.520
# 16               Iceland     4310.000
# 17                Israel     7215.840
# 18                 Italy    17483.240
# 19                 Japan    37416.370
# 20               Lebanon     1693.880
# 21             Lithuania     1661.060
# 22                 Malta     2725.590
# 23           Netherlands   285446.340
# ...

# %%
plt.figure(figsize=(10, 10))
sns.barplot(data=df_vis,
    x="TotalPrice",
    y="Country")
# Out:
# <Axes: xlabel='TotalPrice', ylabel='Country'>

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk = df_adj.query("Country == 'United Kingdom'")
df_uk
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %%
# This is per row, does not care about he quantity (so product with quantity = 1 & product with quantity = 200 will be treated the same)


# #We have to inclued quantity
df_uk.groupby("StockCode", as_index = False).count().loc[:,["StockCode", "Quantity"]].sort_values(by='Quantity', ascending=False).head(10)
# Out:
#      StockCode  Quantity
# 3341    85123A      1936
# 3335    85099B      1461
# 1216     22423      1417
# 2600     84879      1320
# 2404     47566      1300
# 99       20725      1135
# 101      20727      1022
# 1498     22720      1013
# 1961     23203       993
# 1182     22383       977

# %%
most = df_uk.groupby("StockCode", as_index = False)["Quantity"].sum().loc[:,["StockCode", "Quantity"]].sort_values(by='Quantity', ascending=False)
most.head(10)
# Out:
#      StockCode  Quantity
# 2327     23843     80995
# 1925     23166     76919
# 2497     84077     49086
# 1016     22197     45609
# 3335    85099B     41878
# 3341    85123A     34687
# 2600     84879     32628
# 1397     22616     24321
# 37       17003     22675
# 352      21212     22442

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=most.head(10),
    x="StockCode",
    y="Quantity")
# Out:
# <Axes: xlabel='StockCode', ylabel='Quantity'>

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with using **Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt
from datetime import datetime
from datetime import timedelta

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
#Seeing the head of the data of uk
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
#Seeing the describtion of the data of uk
df_uk.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  349203.000000                         349203  349203.000000
# mean       12.145672  2011-07-11 03:25:52.818962176       2.972328
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         2.000000            2011-04-07 11:40:00       1.250000
# 50%         4.000000            2011-07-31 13:37:00       1.950000
# 75%        12.000000            2011-10-23 11:07:30       3.750000
# max     80995.000000            2011-12-09 12:49:00    8142.750000
# std       190.628818                            NaN      17.990908
#
#           CustomerID     TotalPrice
# count  349203.000000  349203.000000
# mean    15548.384252      20.861862
# min     12346.000000       0.001000
# 25%     14191.000000       4.200000
# 50%     15518.000000      10.200000
# 75%     16931.000000      17.850000
# max     18287.000000  168469.600000
# std      1594.384044     328.417275

# %%
#Seeing the info
df_uk.info()
#As we can see, there is datetime64 in the data, so we have to convert it later.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 349203 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349203 non-null  object
#  1   StockCode    349203 non-null  object
#  2   Description  349203 non-null  object
#  3   Quantity     349203 non-null  int64
#  4   InvoiceDate  349203 non-null  datetime64[ns]
#  5   UnitPrice    349203 non-null  float64
#  6   CustomerID   349203 non-null  float64
#  7   Country      349203 non-null  object
#  8   TotalPrice   349203 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 26.6+ MB

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
#last date available in our dataset
df_uk['InvoiceDate'].max()

import datetime as dt

now = dt.date(2011,12,31)
print(now)
# Out:
# 2011-12-31

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
#create a new column called date which contains the only the date of invoice
df_uk['date'] = df_uk['InvoiceDate'].dt.date

df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#          date
# 0  2010-12-01
# 1  2010-12-01
# 2  2010-12-01
# 3  2010-12-01
# 4  2010-12-01

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
customer_recency = pd.DataFrame(df_uk.groupby('CustomerID', as_index=False)['date'].max())
customer_recency.columns = ['CustomerID','LastPurshaceDate']
customer_recency.head()
# Out:
#    CustomerID LastPurshaceDate
# 0     12346.0       2011-01-18
# 1     12747.0       2011-12-07
# 2     12748.0       2011-12-09
# 3     12749.0       2011-12-06
# 4     12820.0       2011-12-06

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
customer_recency['Recency'] = customer_recency['LastPurshaceDate'].apply(lambda x: (now - x).days)
customer_recency.head()
# Out:
#    CustomerID LastPurshaceDate  Recency
# 0     12346.0       2011-01-18      347
# 1     12747.0       2011-12-07       24
# 2     12748.0       2011-12-09       22
# 3     12749.0       2011-12-06       25
# 4     12820.0       2011-12-06       25

# %%
# df_uk['Last_Purchase_Date'] = df_uk['date'].apply(lambda x: (now - x).days)
# df_uk.head()

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
customer_recency.drop('LastPurshaceDate',axis=1,inplace=True)

# %% [markdown]
# 6. Plot RFM distributions

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot RFM distributions using histograms
plt.figure(figsize=(12, 4))

# Plot Recency distribution
# plt.subplot(1, 3, 1)
plt.hist(customer_recency['Recency'], bins=10, color='skyblue')
plt.title('Recency Distribution')
plt.xlabel('Recency')
plt.ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# **- From here, we can say that the majority of customers have just purchased at most half year ago**
# <br>
# **- As we can see, from here we can see that in the end of the year, there were a lot of people who brought, compared to the other days of the year (maybe because of holidays season such as Christmas & thanksgiving)**

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
Freq = df_uk.copy()

# %%
Freq.duplicated().sum()
# Out:
# 0

# %% [markdown]
# But we want to count each invoice just ones since we are interested in number of purchases

# %%
df_uk_copy_ = Freq.drop_duplicates(subset=['InvoiceNo'], keep="first")
print(df_uk_copy_.shape)
# Out:
# (16646, 10)

# %%
df_uk_copy_
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 21        536368     22960             JAM MAKING SET WITH JARS         6
# 25        536369     21756             BATH BUILDING BLOCK WORD         3
# ...          ...       ...                                  ...       ...
# 541863    581582     23552         BICYCLE PUNCTURE REPAIR KIT          6
# 541865    581583     20725              LUNCH BAG RED RETROSPOT        40
# 541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME        72
# 541869    581585     22481       BLACK TEA TOWEL CLASSIC DESIGN        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# ...

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
frequency_data = df_uk_copy_.groupby(by=['CustomerID'], as_index=False)['InvoiceNo'].count().rename({"InvoiceNo":"Frequency"}, axis=1)
frequency_data
# Out:
#       CustomerID  Frequency
# 0        12346.0          1
# 1        12747.0         11
# 2        12748.0        209
# 3        12749.0          5
# 4        12820.0          4
# ...          ...        ...
# 3915     18280.0          1
# 3916     18281.0          1
# 3917     18282.0          2
# 3918     18283.0         16
# 3919     18287.0          3
#
# [3920 rows x 2 columns]

# %% [markdown]
# 3. Plot RFM distributions

# %%
frequency_data.describe()
# Out:
#          CustomerID    Frequency
# count   3920.000000  3920.000000
# mean   15562.059694     4.246429
# std     1576.594671     7.199202
# min    12346.000000     1.000000
# 25%    14208.750000     1.000000
# 50%    15569.500000     2.000000
# 75%    16913.250000     5.000000
# max    18287.000000   209.000000

# %%
# Plot Frequency distribution
plt.hist(frequency_data['Frequency'], bins=20, color='lightgreen')
plt.title('Frequency Distribution')
plt.xlabel('Frequency')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
frequency_data["sqrt_freq"] = frequency_data["Frequency"] ** 0.5

# Plot Frequency distribution
plt.hist(frequency_data['sqrt_freq'], bins=10, color='lightgreen')
plt.title('Frequency Distribution')
plt.xlabel('SQRT Frequency')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# (The third quartile is the value below which 75% of the data falls)
# <br>
# The majority of customers (75% of them) purchases just five times or less :(

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
Monetary_data = df_uk_copy_.groupby("CustomerID")[["TotalPrice"]].sum().sort_values("TotalPrice", ascending = False)
Monetary_data= Monetary_data.rename({"TotalPrice":"Monetary"}, axis=1)
Monetary_data
# Out:
#              Monetary
# CustomerID
# 16446.0     168471.25
# 12346.0      77183.60
# 18102.0      42053.60
# 15098.0      39916.50
# 17949.0      29999.69
# ...               ...
# 14041.0          0.58
# 15645.0          0.42
# 15503.0          0.42
# 13271.0          0.39
# 17914.0          0.39
#
# [3920 rows x 1 columns]

# %%
# To check
df_uk_copy_.query("CustomerID == 16446.0")
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 194354    553573     22980       PANTRY SCRUBBING BRUSH         1
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 194354 2011-05-18 09:52:00       1.65     16446.0  United Kingdom        1.65
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom   168469.60
#
#               date
# 194354  2011-05-18
# 540421  2011-12-09

# %% [markdown]
# 2. Plot RFM distributions

# %%
Monetary_data.describe()
# Out:
#             Monetary
# count    3920.000000
# mean      293.468816
# std      3262.220180
# min         0.390000
# 25%        17.700000
# 50%        45.400000
# 75%       124.537500
# max    168471.250000

# %%
# Plot Monetary value distribution
plt.hist(Monetary_data['Monetary'], bins=20, color='lightcoral')
plt.title('Monetary Value Distribution')
plt.xlabel('Monetary Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
Monetary_data['ln_Monetary'] = Monetary_data['Monetary'] ** 0.5

plt.hist(Monetary_data['ln_Monetary'], bins=10, color='lightcoral')
plt.title('Monetary Value Distribution')
plt.xlabel('Monetary Value')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Even Monetary is highly skewed to the right
# <br>
# The majority (around 75%) customers just purchased in total of 125 price unit or less

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
# Merge the three datasets: Recency, Frequency, Monetary
RFM_data = customer_recency.merge(frequency_data.merge(Monetary_data,on='CustomerID'),on='CustomerID')
RFM_data.head()
# Out:
#    CustomerID  Recency  Frequency  sqrt_freq  Monetary  ln_Monetary
# 0     12346.0      347          1   1.000000  77183.60   277.819366
# 1     12747.0       24         11   3.316625    689.49    26.258142
# 2     12748.0       22        209  14.456832   3841.31    61.978303
# 3     12749.0       25          5   2.236068     98.35     9.917157
# 4     12820.0       25          4   2.000000     58.20     7.628892

# %%
# Drop unnecessary columns
RFM_data = RFM_data.drop(["ln_Monetary", "sqrt_freq"], axis=1)
RFM_data.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     12346.0      347          1  77183.60
# 1     12747.0       24         11    689.49
# 2     12748.0       22        209   3841.31
# 3     12749.0       25          5     98.35
# 4     12820.0       25          4     58.20

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
quantiles = RFM_data.quantile(q = [0.25, 0.50, 0.75])
quantiles
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0.25    14208.75     39.0        1.0   17.7000
# 0.50    15569.50     72.0        2.0   45.4000
# 0.75    16913.25    164.0        5.0  124.5375

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
RFM_data
# Out:
#       CustomerID  Recency  Frequency  Monetary
# 0        12346.0      347          1  77183.60
# 1        12747.0       24         11    689.49
# 2        12748.0       22        209   3841.31
# 3        12749.0       25          5     98.35
# 4        12820.0       25          4     58.20
# ...          ...      ...        ...       ...
# 3915     18280.0      299          1     23.70
# 3916     18281.0      202          1      5.04
# 3917     18282.0       29          2     38.25
# 3918     18283.0       25         16     66.75
# 3919     18287.0       64          3     80.40
#
# [3920 rows x 4 columns]

# %%
quantiles[["Frequency"]].iloc[1,0]
# Out:
# 2.0

# %%
#Defining the function of 
def recency_score(RFM_data):
    if RFM_data.Recency <= quantiles[["Recency"]].iloc[0,0]:
        recency_score = 4
    elif RFM_data.Recency <= quantiles[["Recency"]].iloc[1,0]:
        recency_score = 3
    elif RFM_data.Recency <= quantiles[["Recency"]].iloc[2,0]:
        recency_score = 2
    else:
        recency_score = 1
    return recency_score


# def frequancy_score(RFM_data, RFM_data2):
#     if RFM_data.Frequency <= quantiles[["Frequency"]].iloc[0,0] and RFM_data2.Monetary <= quantiles[["Monetary"]].iloc[0,0]:
#         recency_score = 1
#     elif RFM_data.Frequency <= quantiles[["Frequency"]].iloc[1,0] and RFM_data2.Monetary <= quantiles[["Monetary"]].iloc[0,0]:
#         recency_score = 2
#     elif RFM_data.Frequency <= quantiles[["Frequency"]].iloc[2,0] and RFM_data2.Monetary <= quantiles[["Monetary"]].iloc[0,0]:
#         recency_score = 3
#     else:
#         recency_score = 4
#     return recency_score

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
#Defining the first of frequency_monetary
def frequency_monetary_score(RFM_data, quantiles):
    if RFM_data.Frequency <= quantiles[["Frequency"]].iloc[2,0]:
        frequency_score = 4
    elif RFM_data.Frequency <= quantiles[["Frequency"]].iloc[1,0]:
        frequency_score = 3
    elif RFM_data.Frequency <= quantiles[["Frequency"]].iloc[0,0]:
        frequency_score = 2
    else:
        frequency_score = 1
        
    if RFM_data.Monetary <= quantiles[["Monetary"]].iloc[2,0]:
        monetary_score = 4
    elif RFM_data.Monetary <= quantiles[["Monetary"]].iloc[1,0]:
        monetary_score = 3
    elif RFM_data.Monetary <= quantiles[["Monetary"]].iloc[0,0]:
        monetary_score = 2
    else:
        monetary_score = 1
        
    return max(frequency_score, monetary_score)

# %%
#Creating a Recency_Score column and store the result in it
RFM_data['Recency_Score'] = RFM_data.apply(recency_score, axis=1)
RFM_data.sample(10)
# Out:
#       CustomerID  Recency  Frequency  Monetary  Recency_Score
# 1658     15159.0       23         30    878.25              4
# 3518     17724.0       93          3     68.40              2
# 2191     15880.0      391          1     16.95              1
# 3843     18183.0      249          2     29.95              1
# 994      14224.0      132          4     54.25              2
# 3003     17001.0       22         11    229.90              4
# 910      14107.0       73          7    184.92              2
# 1737     15263.0      128          1     17.40              2
# 420      13402.0      149          2     34.85              2
# 3382     17545.0       65          3     16.15              3

# %%
#Creating a column for FrequencyMonetary_Score and we can add the result in it.
RFM_data['FrequencyMonetary_Score'] = RFM_data.apply(lambda row: frequency_monetary_score(row, quantiles), axis=1)
RFM_data.sample(10)
# Out:
#       CustomerID  Recency  Frequency  Monetary  Recency_Score  \
# 274      13199.0       25         38   3732.76              4
# 1266     14603.0      296          1    150.00              1
# 363      13321.0       94          2    259.04              2
# 161      13045.0      121          1     17.40              2
# 1701     15220.0       73          6    124.65              2
# 1363     14740.0      219          3     42.24              1
# 1326     14691.0       52          5    180.90              3
# 137      13011.0      394          1     15.00              1
# 45       12877.0       25         12    365.79              4
# 1536     15009.0       34          3     66.02              4
#
#       FrequencyMonetary_Score
# 274                         1
# 1266                        4
# 363                         4
# 161                         4
# 1701                        1
# 1363                        4
# 1326                        4
# 137                         4
# ...

# %%
#Seeing the result after adding the two columns
RFM_data
# Out:
#       CustomerID  Recency  Frequency  Monetary  Recency_Score  \
# 0        12346.0      347          1  77183.60              1
# 1        12747.0       24         11    689.49              4
# 2        12748.0       22        209   3841.31              4
# 3        12749.0       25          5     98.35              4
# 4        12820.0       25          4     58.20              4
# ...          ...      ...        ...       ...            ...
# 3915     18280.0      299          1     23.70              1
# 3916     18281.0      202          1      5.04              1
# 3917     18282.0       29          2     38.25              4
# 3918     18283.0       25         16     66.75              4
# 3919     18287.0       64          3     80.40              3
#
#       FrequencyMonetary_Score
# 0                           4
# 1                           1
# 2                           1
# 3                           4
# 4                           4
# ...                       ...
# ...

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
#Creating a new column to add the total scores in it.
RFM_data['Segmentation_Score'] = RFM_data['Recency_Score'] + RFM_data['FrequencyMonetary_Score']
RFM_data
# Out:
#       CustomerID  Recency  Frequency  Monetary  Recency_Score  \
# 0        12346.0      347          1  77183.60              1
# 1        12747.0       24         11    689.49              4
# 2        12748.0       22        209   3841.31              4
# 3        12749.0       25          5     98.35              4
# 4        12820.0       25          4     58.20              4
# ...          ...      ...        ...       ...            ...
# 3915     18280.0      299          1     23.70              1
# 3916     18281.0      202          1      5.04              1
# 3917     18282.0       29          2     38.25              4
# 3918     18283.0       25         16     66.75              4
# 3919     18287.0       64          3     80.40              3
#
#       FrequencyMonetary_Score  Total_score
# 0                           4            5
# 1                           1            5
# 2                           1            5
# 3                           4            8
# ...

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales). We can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into different categories, we can gain further insight into customer behavior by using unsupervised models in conjuction with out RFM model.
# Unsupervised Learning has also been widely used for market segmentation and has the advantage of being simple to implement. Possible algorithms include **K-means Clustering**, **Aglomerative Clustering**, and **Gaussian Mixtute**.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. Logarithmic Tranformation can be used to normalize the values in a column.
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %% [markdown]
# ## Clustering Implementation
#
# Try to apply different clustering algoritms to gather clusters like you achieved in manual RFM analysis.

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %% [markdown]
# ### iv. Assign the Label

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the RFM Customer Segmentation with the labels found by Unsupervised Algorithms.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Conclusion**
#
# * Write down your conclusions about clustering

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 separate series for each of the two columns

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
